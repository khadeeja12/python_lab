# %%
import pandas as pd
import numpy as np

# %% [markdown]
# DataFrame function :

# %%
data={
    'Name':['khadeeja','Faris','Manu','sahala'],
    'Age':[22,19,23,24],
    'City':['Kerala','Mumbai','Delhi','Kolkata']
}
df=pd.DataFrame(data)
print(df)
print(data)
# Out:
#        Name  Age     City
# 0  khadeeja   22   Kerala
# 1     Faris   19   Mumbai
# 2      Manu   23    Delhi
# 3    sahala   24  Kolkata
# {'Name': ['khadeeja', 'Faris', 'Manu', 'sahala'], 'Age': [22, 19, 23, 24], 'City': ['Kerala', 'Mumbai', 'Delhi', 'Kolkata']}

# %%
data1=['khadeeja',22,'kerala'],['Faris',19,'Mumbai'],['Manu',23,'Delhi'],['sahala',24,'Kolkata']
df1=pd.DataFrame(data1,columns=['Name','Age','City'])
print(df1)
# Out:
#        Name  Age     City
# 0  khadeeja   22   kerala
# 1     Faris   19   Mumbai
# 2      Manu   23    Delhi
# 3    sahala   24  Kolkata

# %% [markdown]
# if we want to take it from csv file

# %%
df=pd.read_csv('/content/sample_data.csv')
print(df)
df
print(df.head())
print(df.tail())
print(df.shape)
print(df.columns)
print(df.info())
print(df.describe())
print(df.isnull())
print(df.isnull().sum())
print(df.dtypes)
# Out:
#      ID      Name  Age      City     Salary
# 0     1    Name_1   56   Phoenix  117895.35
# 1     2    Name_2   69  New York   66993.33
# 2     3    Name_3   46  New York   32974.57
# 3     4    Name_4   32  New York   61056.41
# 4     5    Name_5   60  New York   87091.62
# ..  ...       ...  ...       ...        ...
# 95   96   Name_96   42   Phoenix   55160.43
# 96   97   Name_97   62  New York  109514.46
# 97   98   Name_98   58  New York   97294.69
# 98   99   Name_99   46   Chicago  115776.47
# 99  100  Name_100   32  New York   59767.53
#
# [100 rows x 5 columns]
#    ID    Name  Age      City     Salary
# 0   1  Name_1   56   Phoenix  117895.35
# 1   2  Name_2   69  New York   66993.33
# 2   3  Name_3   46  New York   32974.57
# 3   4  Name_4   32  New York   61056.41
# 4   5  Name_5   60  New York   87091.62
#      ID      Name  Age      City     Salary
# 95   96   Name_96   42   Phoenix   55160.43
# 96   97   Name_97   62  New York  109514.46
# ...

# %%
df=pd.read_excel('/content/sample_data.xlsx')
print(df)
# Out:
#      ID      Name  Age      City     Salary
# 0     1    Name_1   56   Phoenix  117895.35
# 1     2    Name_2   69  New York   66993.33
# 2     3    Name_3   46  New York   32974.57
# 3     4    Name_4   32  New York   61056.41
# 4     5    Name_5   60  New York   87091.62
# ..  ...       ...  ...       ...        ...
# 95   96   Name_96   42   Phoenix   55160.43
# 96   97   Name_97   62  New York  109514.46
# 97   98   Name_98   58  New York   97294.69
# 98   99   Name_99   46   Chicago  115776.47
# 99  100  Name_100   32  New York   59767.53
#
# [100 rows x 5 columns]

# %%
print(df[['Name','Age']])
print(df.iloc[0])
print(df.iloc[0:2])
print(df.iloc[0:2,0:2])

print(df.loc[0:2,'Name'])

print(df.loc[0:2,'Name':'Age'])
# Out:
#         Name  Age
# 0     Name_1   56
# 1     Name_2   69
# 2     Name_3   46
# 3     Name_4   32
# 4     Name_5   60
# ..       ...  ...
# 95   Name_96   42
# 96   Name_97   62
# 97   Name_98   58
# 98   Name_99   46
# 99  Name_100   32
#
# [100 rows x 2 columns]
# ID                1
# Name         Name_1
# Age              56
# City        Phoenix
# Salary    117895.35
# Name: 0, dtype: object
#    ID    Name  Age      City     Salary
# 0   1  Name_1   56   Phoenix  117895.35
# 1   2  Name_2   69  New York   66993.33
#    ID    Name
# 0   1  Name_1
# 1   2  Name_2
# 0    Name_1
# 1    Name_2
# 2    Name_3
# Name: Name, dtype: object
#      Name  Age
# 0  Name_1   56
# 1  Name_2   69
# 2  Name_3   46

# %%
print(df[df['Age']>20])
print(df[(df['Age']>20) & (df['City']=='Kerala')])
# Out:
#      ID      Name  Age      City     Salary
# 0     1    Name_1   56   Phoenix  117895.35
# 1     2    Name_2   69  New York   66993.33
# 2     3    Name_3   46  New York   32974.57
# 3     4    Name_4   32  New York   61056.41
# 4     5    Name_5   60  New York   87091.62
# ..  ...       ...  ...       ...        ...
# 95   96   Name_96   42   Phoenix   55160.43
# 96   97   Name_97   62  New York  109514.46
# 97   98   Name_98   58  New York   97294.69
# 98   99   Name_99   46   Chicago  115776.47
# 99  100  Name_100   32  New York   59767.53
#
# [94 rows x 5 columns]
# Empty DataFrame
# Columns: [ID, Name, Age, City, Salary]
# Index: []

# %%
df['New_column']=df['Age']+10
df
df=df.drop('New_column',axis=1)
df
# Out:
#      ID      Name  Age      City     Salary
# 0     1    Name_1   56   Phoenix  117895.35
# 1     2    Name_2   69  New York   66993.33
# 2     3    Name_3   46  New York   32974.57
# 3     4    Name_4   32  New York   61056.41
# 4     5    Name_5   60  New York   87091.62
# ..  ...       ...  ...       ...        ...
# 95   96   Name_96   42   Phoenix   55160.43
# 96   97   Name_97   62  New York  109514.46
# 97   98   Name_98   58  New York   97294.69
# 98   99   Name_99   46   Chicago  115776.47
# 99  100  Name_100   32  New York   59767.53
#
# [100 rows x 5 columns]

# %% [markdown]
# finding the missing values

# %%
df=df.fillna(0)
df
df=df.dropna()
df
# Out:
#      ID      Name  Age      City     Salary
# 0     1    Name_1   56   Phoenix  117895.35
# 1     2    Name_2   69  New York   66993.33
# 2     3    Name_3   46  New York   32974.57
# 3     4    Name_4   32  New York   61056.41
# 4     5    Name_5   60  New York   87091.62
# ..  ...       ...  ...       ...        ...
# 95   96   Name_96   42   Phoenix   55160.43
# 96   97   Name_97   62  New York  109514.46
# 97   98   Name_98   58  New York   97294.69
# 98   99   Name_99   46   Chicago  115776.47
# 99  100  Name_100   32  New York   59767.53
#
# [100 rows x 5 columns]

# %% [markdown]
# # New Section
